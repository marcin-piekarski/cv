# %%
# %matplotlib inline
import cv2
print("OpenCV Version : %s " % cv2.__version__)

# %%
pth = r'C:\Users\mbess\Dev\practical_python_and_opencv\code\images'

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import numpy as np

image = mpimg.imread(pth + r'\trex.png')


print("width: %d pixels" % (image.shape[1]))
print("height: %d pixels" % (image.shape[0]))
print("channels: %d" % (image.shape[2]))

plt.imshow(image)
# Out:
# width: 350 pixels
# height: 228 pixels
# channels: 3

# %% [markdown]
# ##### MATRIX NOTE
# - matrixs normally written in the form ROWS x COLUMNS
# - NumPy writes the inverse: COLUMNS x ROWS

# %% [markdown]
# ## PIXEL
#
# - every image is a set of pixels.
# - analogous to a grid
# - represented as grayscale or color
#
#
#
# #### GRAYSCALE
#
# - value 0 - 255
# - 0 = black, 255 = white
# - values closer to 0 are darker
# - values closer to 255 are lighter
#
#
# #### COLOR
# - Often represented as the RGB colorspace.
# - Many colorspaces exist, but RGB is commonplace
# - consist of a tuple of three integer values between 0 - 255.
# - value set indicates how much of each color (R, G, B) is present in the pixel
# - white is made using (255, 255, 255);   black is (0, 0, 0)

# %%
# create dictionary of common colors

commonColors = dict(black=(0, 0, 0), white=(255, 255, 255), red=(255,0,0), 
green=(0,255,0), blue=(0,0,255), aqua=(0,255,255), 
fuchsia=(255,0,255), maroon=(128,0,0), navy=(0,0,128), 
olive=(128,128,0), purple=(128,0,128), teal=(0,128,128), 
yellow=(255, 255, 0))

print(commonColors)
# Out:
# {'red': (255, 0, 0), 'green': (0, 255, 0), 'yellow': (255, 255, 0), 'fuchsia': (255, 0, 255), 'navy': (0, 0, 128), 'teal': (0, 128, 128), 'black': (0, 0, 0), 'aqua': (0, 255, 255), 'maroon': (128, 0, 0), 'olive': (128, 128, 0), 'purple': (128, 0, 128), 'blue': (0, 0, 255), 'white': (255, 255, 255)}

# %% [markdown]
# ___
# pg - 20

# %%
plt.imshow(image)

# %%
(b, g, r) = image[0, 0]
print("Pixel at (0, 0) Red: %d, Green: %d, Blue: %d" % (r, g, b))
# Out:
# Pixel at (0, 0) Red: 0, Green: 0, Blue: 0

# %%
image[0, 0] = (0, 0, 255)
(b, g, r) = image[0, 0]
print("Pixel at (0, 0) Red: %d, Green: %d, Blue: %d" % (r, g, b))
# Out:
# Pixel at (0, 0) Red: 255, Green: 0, Blue: 0

# %% [markdown]
# ___
# pg - 22

# %%
corner = image[0:100, 0:100]
plt.imshow(corner)

# %%
image[0:100, 0:100] = (0, 175, 0)

plt.imshow(image)

# %% [markdown]
# ___
# ### Lines and Rectangles
